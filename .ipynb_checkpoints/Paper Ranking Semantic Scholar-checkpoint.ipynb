# %%
import requests
import json
import threading
import re
import spacy
from datetime import date
from operator import itemgetter

todays_date = date.today()
sp = spacy.load('en_core_web_sm')

def citations_per_paper_score(citations, number_of_papers):
    
    citations = int(citations)
    number_of_papers = int(number_of_papers)
    
    citations_per_paper = citations / number_of_papers
    if citations_per_paper < 5 :
        return 0.03 * citations_per_paper
    else :
        return 0.15
    
def publications_per_year_score(publication, exp):
    
    publication = int(publication)
    exp = int(exp)
    
    publications_per_year = publication / (exp)
    if publications_per_year < 3:
        return 0.15 * publications_per_year / 2
    elif publications_per_year < 6:
        return 0.15 * (6 - publications_per_year) / 2
    else:
        return 0
    
def experience(data):
    
    end_year = 0
    start_year = 3000
    try : 
        
        for paper in data['papers']:
            if(paper['year'] > end_year):
                end_year = paper['year']
            if(paper['year'] < start_year):
                start_year = paper['year']

        exp = end_year - start_year + 1
        return exp
    except:
        return 1
    
def experience_score(start_year, end_year):
    time_duration = end_year - start_year + 1
    if time_duration < 16:
        return 0.15 * time_duration / 15
    else:
        return 0.15
    
def check_topic_relevance(keywords, data):
    score = 0
    for papers in data['papers']:
        for publication_topics in papers['title']:
            text_tokens = list(keywords)
            publication_topics = list(publication_topics)
            all_stopwords = sp.Defaults.stop_words
            tokens_without_stopwords = [word for word in text_tokens if not word in all_stopwords]
            relevant_topics = [word for word in tokens_without_stopwords for topic in publication_topics if topic == word]
            if len(relevant_topics) == len(tokens_without_stopwords):
                score += 0.02
            else:
                score += 0.02 * len(relevant_topics) / len(tokens_without_stopwords)
    
    return score/50

def hIndex(data):
    return data['hIndex']/30
    
def authorJson(authorId):
    URL = "https://api.semanticscholar.org/graph/v1/author/" + (authorId) + "?fields=url,name,affiliations,paperCount,citationCount,hIndex,papers.title,papers.year"
    data = (requests.get(url = URL )).json()
    return data
    
def authorScore(keywords,authorId):
    
    data = authorJson(authorId)
    exp = experience(data)
    ppy_score = publications_per_year_score(str(data['paperCount']),str(exp))
    cpp_score = citations_per_paper_score(str(data['citationCount']),str(data['paperCount']))
    ctr_score = check_topic_relevance(keywords,data)
    hi_score = hIndex(data)
    
    authorScore = ppy_score + cpp_score + ctr_score + hi_score

    return authorScore

def influential_citation_count(paper):
    score = paper['influentialCitationCount']
    if(score < 50):
        return score/250
    else:
        return 0.5
    
def authorList(paper):
    authors = paper['authors']
    authorList = []
    i = 1;
    for author in authors:
        dict = {}
        data = authorJson(author['authorId'])
        try:
            dict['affiliation'] = data['affiliations'][0]
        except:
            dict['affiliation'] = " "
        dict['authorUrl'] = data['url']
        dict['id'] = data['authorId']
        dict['full_name'] = data['name']
        dict['author_order'] = i
        i = i + 1
        authorList.append(dict)
    
    return authorList
    
    
def citation_per_year(paper):
    score = (paper['citationCount'] / (todays_date.year - paper['year']))
    if(score < 50):
        return score/250
    else:
        return 0.5
    
def papers(keywords):
    tokens = keywords.split(" ")
    tokenString = '+'.join(tokens)
    URL = "https://api.semanticscholar.org/graph/v1/paper/search?query=" + tokenString + "&offset=10&limit=10&fields=title,url,authors,abstract,year,referenceCount,citationCount,influentialCitationCount,journal,publicationDate"
    return ((requests.get(url = URL )).json()['data'])

def ranking(keywords):
    researchPapers = papers(keywords)
    articles = []
    for paper in researchPapers:
        dict = {}
        
        authors = paper['authors']
        numberOfAuthors = len(authors)
        author_score = 0
        if(numberOfAuthors == 1):
            author_score = (authorScore(keywords,authors[0]['authorId']))
        else:
            author_score = ((authorScore(keywords,authors[0]['authorId'])) + (authorScore(keywords,authors[1]['authorId']))) / 2
        authorsList = authorList(paper)
        try:
            dict['title'] = paper['title']
        except:
            dict['title'] = " "
        try:
             dict['pdf_url'] = paper['url']
        except:
             dict['pdf_url'] = " "
        try:
            dict['abstract'] = paper['abstract']
        except:
            dict['abstract'] = " "
        try:
            dict['publication_year'] = paper['year']
        except:
            dict['publication_year'] = " "
        try:
            dict['citing_paper_count'] = paper['citationCount']
        except:
            dict['citing_paper_count'] = " "
        try:
            dict['influenceScore'] = paper['influentialCitationCount']
        except:
            dict['influenceScore'] = " "
        try:
            dict['auhtorScore'] = str(author_score)
        except:
            dict['auhtorScore'] = " "
        try:
            dict['paperScore'] = (author_score + citation_per_year(paper))
        except:
            dict['paperScore'] = 0
        try:
            dict['publication_date'] = paper['publicationDate']
        except:
            dict['publication_date'] = " "

        dict['publisher'] = " "
        
        try:
            dict['journal'] = paper['journal']['name']
        except:
            dict['journal'] = " "
        try:
            dict['authors'] = {"authors" : authorsList}
        except:
            dict['authors'] = {"authors" : []}
        
        articles.append(dict)
        
    articles = sorted(articles, key=itemgetter('paperScore'), reverse=True)
    return {"articles" : articles}

# %%
print(ranking("Image Analysis"))
# Out:
# {'title': 'Deep learning with noisy labels: exploring techniques and remedies in medical image analysis', 'pdf_url': 'https://www.semanticscholar.org/paper/7e40d5d095db557810ae9560db33a3c2a09e630c', 'abstract': None, 'publication_year': 2019, 'citing_paper_count': 209, 'influenceScore': 15, 'auhtorScore': '0.6788545454545476', 'paperScore': 1.1788545454545476, 'publication_date': '2019-12-05', 'publisher': ' ', 'journal': 'Medical image analysis', 'authors': {'authors': [{'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/2130813', 'id': '2130813', 'full_name': 'D. Karimi', 'author_order': 1}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/10669778', 'id': '10669778', 'full_name': 'Haoran Dou', 'author_order': 2}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/145502062', 'id': '145502062', 'full_name': 'S. Warfield', 'author_order': 3}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/143936525', 'id': '143936525', 'full_name': 'A. Gholipour', 'author_order': 4}]}}
# {'title': 'GANs for Medical Image Analysis', 'pdf_url': 'https://www.semanticscholar.org/paper/04507020e4e003042150dcc8602505d1bec71c49', 'abstract': None, 'publication_year': 2018, 'citing_paper_count': 176, 'influenceScore': 7, 'auhtorScore': '0.5556393939393938', 'paperScore': 0.7316393939393937, 'publication_date': '2018-09-13', 'publisher': ' ', 'journal': 'Artificial intelligence in medicine', 'authors': {'authors': [{'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/47358764', 'id': '47358764', 'full_name': 'Salome Kazeminia', 'author_order': 1}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/1720766387', 'id': '1720766387', 'full_name': 'Christoph Baur', 'author_order': 2}, {'affiliation': 'Fraunhofer IGD', 'authorUrl': 'https://www.semanticscholar.org/author/145307900', 'id': '145307900', 'full_name': 'Arjan Kuijper', 'author_order': 3}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/8038506', 'id': '8038506', 'full_name': 'B. Ginneken', 'author_order': 4}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/145587210', 'id': '145587210', 'full_name': 'Nassir Navab', 'author_order': 5}, {'affiliation': 'TU Munich', 'authorUrl': 'https://www.semanticscholar.org/author/3098247', 'id': '3098247', 'full_name': 'Shadi Albarqouni', 'author_order': 6}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/144241818', 'id': '144241818', 'full_name': 'A. Mukhopadhyay', 'author_order': 7}]}}
# {'title': 'Deep Learning in Medical Image Analysis.', 'pdf_url': 'https://www.semanticscholar.org/paper/193532f7dab6481d4feaef9350e4fd6c434920e7', 'abstract': None, 'publication_year': 2017, 'citing_paper_count': 135, 'influenceScore': 3, 'auhtorScore': '2.2616438502671383', 'paperScore': 2.3696438502671384, 'publication_date': '2017-01-30', 'publisher': ' ', 'journal': 'Advances in experimental medicine and biology', 'authors': {'authors': [{'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/1905897', 'id': '1905897', 'full_name': 'H. Chan', 'author_order': 1}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/3423854', 'id': '3423854', 'full_name': 'Ravi K. Samala', 'author_order': 2}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/2591670', 'id': '2591670', 'full_name': 'L. Hadjiiski', 'author_order': 3}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/1643124213', 'id': '1643124213', 'full_name': 'Chuan Zhou', 'author_order': 4}]}}
# {'title': 'CellProfiler: image analysis software for identifying and quantifying cell phenotypes', 'pdf_url': 'https://www.semanticscholar.org/paper/a2e75b7d9727b7ea7cefb4060d93ac75813e3c48', 'abstract': None, 'publication_year': 2006, 'citing_paper_count': 4082, 'influenceScore': 366, 'auhtorScore': '1.9297939393939305', 'paperScore': 2.4297939393939307, 'publication_date': '2006-10-31', 'publisher': ' ', 'journal': 'Genome Biology', 'authors': {'authors': [{'affiliation': 'Broad Institute', 'authorUrl': 'https://www.semanticscholar.org/author/1721012', 'id': '1721012', 'full_name': 'Anne E Carpenter', 'author_order': 1}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/2646100', 'id': '2646100', 'full_name': 'T. Jones', 'author_order': 2}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/3809951', 'id': '3809951', 'full_name': 'M. R. Lamprecht', 'author_order': 3}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/2061740591', 'id': '2061740591', 'full_name': 'C. Clarke', 'author_order': 4}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/2286503', 'id': '2286503', 'full_name': 'I. Kang', 'author_order': 5}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/3284867', 'id': '3284867', 'full_name': 'O. Friman', 'author_order': 6}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/3173673', 'id': '3173673', 'full_name': 'D. Guertin', 'author_order': 7}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/1633209311', 'id': '1633209311', 'full_name': 'J. Chang', 'author_order': 8}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/47693567', 'id': '47693567', 'full_name': 'Robert A Lindquist', 'author_order': 9}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/143862649', 'id': '143862649', 'full_name': 'J. Moffat', 'author_order': 10}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/1729630', 'id': '1729630', 'full_name': 'P. Golland', 'author_order': 11}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/1843680', 'id': '1843680', 'full_name': 'D. Sabatini', 'author_order': 12}]}}
# {'title': 'Morphological Image Analysis: Principles and Applications', 'pdf_url': 'https://www.semanticscholar.org/paper/4e234772b283e9e274791ed25911c20e08e6c462', 'abstract': 'From the Publisher: \nThe purpose of this book is to provide readers with an in-depth presentation of the principles and applications of morphological image analysis. This is achieved through a step by step process starting from the basic morphological operators and extending to the most recent advances which have proven their practical usefulness. This self-contained volume will be valuable to all engineers, scientists, and practitioners interested in the analysis and processing of digital images.', 'publication_year': 2003, 'citing_paper_count': 4192, 'influenceScore': 314, 'auhtorScore': '1.96100606060607', 'paperScore': 2.4610060606060697, 'publication_date': None, 'publisher': ' ', 'journal': '', 'authors': {'authors': [{'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/2987794', 'id': '2987794', 'full_name': 'P. Soille', 'author_order': 1}]}}
# {'title': 'Object based image analysis for remote sensing', 'pdf_url': 'https://www.semanticscholar.org/paper/c5f804d4b296237f7f0777c2ecf796c92b0c730e', 'abstract': None, 'publication_year': 2010, 'citing_paper_count': 3801, 'influenceScore': 315, 'auhtorScore': '3.0433333333331074', 'paperScore': 3.5433333333331074, 'publication_date': None, 'publisher': ' ', 'journal': 'Isprs Journal of Photogrammetry and Remote Sensing', 'authors': {'authors': [{'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/50594282', 'id': '50594282', 'full_name': 'T. Blaschke', 'author_order': 1}]}}
# {'title': 'A Paradigm for Model Fitting with Applications to Image Analysis and Automated Cartography', 'pdf_url': 'https://www.semanticscholar.org/paper/4f37468a95ccc62debb9e5a4cb0d73489ca61190', 'abstract': None, 'publication_year': 1987, 'citing_paper_count': 5837, 'influenceScore': 1131, 'auhtorScore': '1.6676873138161346', 'paperScore': 2.1676873138161348, 'publication_date': None, 'publisher': ' ', 'journal': ' ', 'authors': {'authors': [{'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/2465976', 'id': '2465976', 'full_name': 'M. Fischler', 'author_order': 1}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/1764443', 'id': '1764443', 'full_name': 'R. Bolles', 'author_order': 2}]}}
# {'title': 'Deep learning for cellular image analysis', 'pdf_url': 'https://www.semanticscholar.org/paper/48cc41c7b2fac21d7bbd2988c5c6a2c5f9744852', 'abstract': None, 'publication_year': 2019, 'citing_paper_count': 506, 'influenceScore': 5, 'auhtorScore': '0.5051522727272728', 'paperScore': 1.0051522727272728, 'publication_date': '2019-05-27', 'publisher': ' ', 'journal': 'Nature Methods', 'authors': {'authors': [{'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/2065614284', 'id': '2065614284', 'full_name': 'Erick Moen', 'author_order': 1}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/91548448', 'id': '91548448', 'full_name': 'Dylan Bannon', 'author_order': 2}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/5864924', 'id': '5864924', 'full_name': 'Takamasa Kudo', 'author_order': 3}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/2054090660', 'id': '2054090660', 'full_name': 'William Graf', 'author_order': 4}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/2835805', 'id': '2835805', 'full_name': 'M. Covert', 'author_order': 5}, {'affiliation': ' ', 'authorUrl': 'https://www.semanticscholar.org/author/6838746', 'id': '6838746', 'full_name': 'David Van Valen', 'author_order': 6}]}}
